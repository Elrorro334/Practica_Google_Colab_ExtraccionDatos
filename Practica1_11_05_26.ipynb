# %% [markdown]
# <a href="https://colab.research.google.com/github/Elrorro334/Practica_Google_Colab_ExtraccionDatos/blob/main/Practica1_11_05_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

# %% [markdown]
# subir dataset

# %%
uploaded = files.upload()
df = pd.read_csv('ventas.csv')
# Out:
#      <input type="file" id="files-93fb5e0a-c475-466b-8520-aefc29f8b799" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93fb5e0a-c475-466b-8520-aefc29f8b799">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# procesamiento de datos
# mostrar las primeras filas

# %%
print("\n Encabezado del dataset")
print(df.head())
# Out:
#  Encabezado del dataset
#    IdVenta   Producto    Categoria  Precio  Cantidad            Ciudad  \
# 0        1     Laptop  Electronica   18500         2  Ciudad de Mexico
# 1        2      Mouse  Electronica     350         5           Pachuca
# 2        3    Teclado  Electronica     750         3         Queretaro
# 3        4    Celular  Electronica    9200         1            Puebla
# 4        5  Audifonos  Electronica    1200         4            Toluca
#
#       MetodoPago
# 0        Tarjeta
# 1       Efectivo
# 2        Tarjeta
# 3  Transferencia
# 4        Tarjeta

# %% [markdown]
# Informacion general del Dataset

# %%
print("\n Informacion del dataset")
print(df.info())
print("\n Descripcion del dataset")
print(df.describe())
# Out:
#  Informacion del dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IdVenta     30 non-null     int64
#  1   Producto    30 non-null     object
#  2   Categoria   30 non-null     object
#  3   Precio      30 non-null     int64
#  4   Cantidad    30 non-null     int64
#  5   Ciudad      30 non-null     object
#  6   MetodoPago  30 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 1.8+ KB
# None
#
#  Descripcion del dataset
#          IdVenta        Precio  Cantidad
# count  30.000000     30.000000  30.00000
# mean   15.500000   2975.833333   5.60000
# std     8.803408   4652.873247   6.91126
# min     1.000000     25.000000   1.00000
# 25%     8.250000    312.500000   2.00000
# 50%    15.500000    950.000000   2.50000
# 75%    22.750000   3325.000000   5.75000
# max    30.000000  18500.000000  30.00000

# %% [markdown]
# Conteo de categorias

# %%
print("\n Cantidad por categoria")
print(df['Categoria'].value_counts())

print("\n Cantidad por pago")
print(df['MetodoPago'].value_counts())

print("\n Proucto mas Caro")
print(df.loc[df['Precio'].idxmax()])
# Out:
#  Cantidad por categoria
# Categoria
# Electronica    8
# Ropa           8
# Alimentos      7
# Hogar          7
# Name: count, dtype: int64
#
#  Cantidad por pago
# MetodoPago
# Tarjeta          12
# Efectivo         11
# Transferencia     7
# Name: count, dtype: int64
#
#  Proucto Caro
# IdVenta                      1
# Producto                Laptop
# Categoria          Electronica
# Precio                   18500
# Cantidad                     2
# Ciudad        Ciudad de Mexico
# MetodoPago             Tarjeta
# Name: 0, dtype: object

# %%
print("\n Promedio y Suma")
print(df['Precio'].mean())
print(df['Cantidad'].sum())
# Out:
#  Promedio y Suma
# 2975.8333333333335
# 168

# %%
print("\n Graficas de Categorias y Ventas")
df['Categoria'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Categoria'>
