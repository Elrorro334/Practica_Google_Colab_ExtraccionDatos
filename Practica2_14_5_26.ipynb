# %% [markdown]
# <a href="https://colab.research.google.com/github/Elrorro334/Practica_Google_Colab_ExtraccionDatos/blob/main/Practica2_14_5_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Problematica:
# Out:
#   File "/tmp/ipykernel_6312/98167900.py", line 1
#     Problematica:
#                  ^
# SyntaxError: invalid syntax
